# %% [markdown]
# <a href="https://colab.research.google.com/github/Torrespy/Estudos/blob/main/Covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 
import pandas as pd
url=('https://pt.wikipedia.org/wiki/Pandemia_de_COVID-19_no_Brasil')
tabela=pd.read_html(url)[4]
tabela.info
display(tabela)
# Out:
#           Região  ... Óbitossecretarias de saúde
# 0        Sudeste  ...                    150 835
# 1        Sudeste  ...                     67 207
# 2        Sudeste  ...                     55 036
# 3        Sudeste  ...                     12 707
# 4            Sul  ...                     35 070
# 5            Sul  ...                     19 431
# 6            Sul  ...                     39 603
# 7       Nordeste  ...                     26 940
# 8       Nordeste  ...                     19 857
# 9       Nordeste  ...                     24 317
# 10      Nordeste  ...                      6 250
# 11      Nordeste  ...                      7 357
# 12      Nordeste  ...                      6 020
# 13      Nordeste  ...                     10 206
# 14      Nordeste  ...                      7 050
# 15      Nordeste  ...                      9 358
# 16  Centro-Oeste  ...                     10 648
# 17  Centro-Oeste  ...                     23 849
# ...
